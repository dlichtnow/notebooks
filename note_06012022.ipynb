# %%
import pandas as pd
file_data = pd.read_csv('arquivo06012022_V1.csv', header=None) 
print(file_data)
num_of_records = len(file_data)
print(num_of_records)
# Out:
#        0       1        2        3
# 0    pao   leite      NaN      NaN
# 1    pao  fralda  cerveja     ovos
# 2  leite  fralda  cerveja     coca
# 3    pao   leite   fralda  cerveja
# 4    pao   leite   fralda     coca
# 5

# %%
records = []
for i in range(0,num_of_records):
    records.append([str(file_data.values[i,j]) for j in range(0,4)])
print(records)
# Out:
# [['pao', 'leite', 'nan', 'nan'], ['pao', 'fralda', 'cerveja', 'ovos'], ['leite', 'fralda', 'cerveja', 'coca'], ['pao', 'leite', 'fralda', 'cerveja'], ['pao', 'leite', 'fralda', 'coca']]

# %%
import numpy as np
from numpy import nan

transactions=[]
for record in records:
    new_record = []
    for item in record:
        if str(item) != 'nan':
            new_record.append(item)
    print(new_record)
    transactions.append(new_record)
print(transactions)
# Out:
# ['pao', 'leite']
# ['pao', 'fralda', 'cerveja', 'ovos']
# ['leite', 'fralda', 'cerveja', 'coca']
# ['pao', 'leite', 'fralda', 'cerveja']
# ['pao', 'leite', 'fralda', 'coca']
# [['pao', 'leite'], ['pao', 'fralda', 'cerveja', 'ovos'], ['leite', 'fralda', 'cerveja', 'coca'], ['pao', 'leite', 'fralda', 'cerveja'], ['pao', 'leite', 'fralda', 'coca']]

# %%
from efficient_apriori import apriori
itemsets, rules = apriori(transactions, min_support=0.2, min_confidence=1)

# %%
for rule in rules:
    print("Regras")
    print(rule)
# Out:
# Regras
# {cerveja} -> {fralda} (conf: 1.000, supp: 0.600, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos} -> {cerveja} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {coca} -> {fralda} (conf: 1.000, supp: 0.400, lift: 1.250, conv: 200000000.000)
# Regras
# {coca} -> {leite} (conf: 1.000, supp: 0.400, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos} -> {pao} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {cerveja, coca} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {cerveja, coca} -> {leite} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {cerveja, leite} -> {fralda} (conf: 1.000, supp: 0.400, lift: 1.250, conv: 200000000.000)
# Regras
# {fralda, ovos} -> {cerveja} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {cerveja, ovos} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos} -> {cerveja, fralda} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {cerveja, pao} -> {fralda} (conf: 1.000, supp: 0.400, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos, pao} -> {cerveja} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {cerveja, ovos} -> {pao} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos} -> {cerveja, pao} (conf: 1.000, supp: 0.200, lift: 2.500, conv: 600000000.000)
# Regras
# {coca, leite} -> {fralda} (conf: 1.000, supp: 0.400, lift: 1.250, conv: 200000000.000)
# Regras
# {coca, fralda} -> {leite} (conf: 1.000, supp: 0.400, lift: 1.250, conv: 200000000.000)
# Regras
# {coca} -> {fralda, leite} (conf: 1.000, supp: 0.400, lift: 1.667, conv: 400000000.000)
# Regras
# {coca, pao} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {coca, pao} -> {leite} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos, pao} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {fralda, ovos} -> {pao} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos} -> {fralda, pao} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {cerveja, coca, leite} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {cerveja, coca, fralda} -> {leite} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {cerveja, coca} -> {fralda, leite} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {cerveja, leite, pao} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {fralda, ovos, pao} -> {cerveja} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {cerveja, ovos, pao} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {cerveja, fralda, ovos} -> {pao} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {ovos, pao} -> {cerveja, fralda} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {fralda, ovos} -> {cerveja, pao} (conf: 1.000, supp: 0.200, lift: 2.500, conv: 600000000.000)
# Regras
# {cerveja, ovos} -> {fralda, pao} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
# Regras
# {ovos} -> {cerveja, fralda, pao} (conf: 1.000, supp: 0.200, lift: 2.500, conv: 600000000.000)
# Regras
# {coca, leite, pao} -> {fralda} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {coca, fralda, pao} -> {leite} (conf: 1.000, supp: 0.200, lift: 1.250, conv: 200000000.000)
# Regras
# {coca, pao} -> {fralda, leite} (conf: 1.000, supp: 0.200, lift: 1.667, conv: 400000000.000)
